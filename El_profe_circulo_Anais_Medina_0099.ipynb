# %% [markdown]
# ### Anais Medina NL Fecha 25/Mar/2026 ❤
# ---
# # Calcular Area y perimetro de un circulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/AnaisMedinaZubia/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/Circulo_area_perimetro.JPG)
#
# ---
#
# ## Formula para calcular area
# $A=\pi*r^2$
#
# ---
#
# ## Formula para calcular perimetro
# $P=2*\pi*r$
#
# ---
#
# ## Datos de entrada
# $r$ ?
#
# ---
#
# ## Diagrama de flujo en lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/AnaisMedinaZubia/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/fc5361dfe497e834fd29df327766a2da2c9d72c2/DF%20Area%20perimetro%20circulo.png)

# %%
# Calcular area y perimetro de un circulo
# Variables A, P, r
# Formulas A = pi*r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor de r: "))
A =math.pi*r**2
P = 2*math.pi*r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Anais Medina NL = 36")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor de r: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
# Anais Medina NL = 36

# %% [markdown]
# # Relacion entre codigo y DF en tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/AnaisMedinaZubia/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/Circulo_area_perimetrotro.JPG)
